# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager import driver
from webdriver_manager.chrome import ChromeDriverManager
import datetime
import pandas as pd
from textblob import TextBlob

# %%
from sqlalchemy import create_engine

# %%
product_link = "https://www.amazon.in/Vivo-Y33s-Storage-Additional-Exchange/dp/B08ZJR6BMV/ref=sr_1_1_sspa?keywords=mobiles&qid=1644125639&sprefix=mobil%2Caps%2C319&sr=8-1-spons&psc=1&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUEzVldHMUxHVVAzRlhQJmVuY3J5cHRlZElkPUEwMDc5NTY0MzBGRUk4Rko0RkY3TCZlbmNyeXB0ZWRBZElkPUEwNzAwMzgwMzQxR1FPSFZZT0daMiZ3aWRnZXROYW1lPXNwX2F0ZiZhY3Rpb249Y2xpY2tSZWRpcmVjdCZkb05vdExvZ0NsaWNrPXRydWU="
driver=webdriver.Chrome(ChromeDriverManager().install())
driver.maximize_window()
driver.get(product_link)
review_page_link = driver.find_element(by='id',value="reviews-medley-footer").find_element_by_css_selector('a.a-link-emphasis').get_attribute('href')
# Out:
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 101.0.4951
# [WDM] - Get LATEST driver version for 101.0.4951
# [WDM] - Get LATEST driver version for 101.0.4951
# [WDM] - Trying to download new driver from https://chromedriver.storage.googleapis.com/101.0.4951.41/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\HP\.wdm\drivers\chromedriver\win32\101.0.4951.41]
# C:\Users\HP\AppData\Local\Temp/ipykernel_29872/1923181662.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(ChromeDriverManager().install())
# C:\Users\HP\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webelement.py:483: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")

# %%
page = 1
review_next_link=f'{review_page_link}&pageNumber={page}'
driver.get(review_next_link)

# %%
review_area = driver.find_element_by_css_selector('#cm_cr-review_list')
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_29872/1081061758.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   review_area = driver.find_element_by_css_selector('#cm_cr-review_list')

# %%
review_list = review_area.find_elements_by_css_selector('.review')
if review_list:
    print(len(review_list))
else:
    print('crap')
# Out:
# 10
# C:\Users\HP\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webelement.py:501: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")

# %%
data=[]
for item in review_list:

    try:
        title=item.find_element_by_css_selector('span.a-profile-name').text
    except:
        title=""
    try:
        date=item.find_element_by_css_selector('span.a-size-base.a-color-secondary.review-date').text
    except:
        date=""
    
    try:
        content=item.find_element_by_css_selector('span.a-size-base.review-text.review-text-content').text
    except:
        content=""
    try:
        rating1=item.find_elements_by_css_selector('i.a-icon-star')[-1]
        rating1 = rating1.get_attribute('class')
        if "5" in rating1:
            rating1 = 5
        elif "4" in rating1:
            rating1=4
        elif "3" in rating1:
            rating1=3
        elif "2" in rating1:
            rating1=2
        elif "1" in rating1:
            rating1=1

    except:
        rating1=""



    data.append({
        'title':title,
        'date':date,
        'content':content,
        'rating':rating1
    })
print(data)
# Out:
# [{'title': 'ANDISAMY C', 'date': 'Reviewed in India on 11 September 2021', 'content': 'கேமரா வேஸ்ட் .தயவு செய்து பணத்தை வேஸ்ட் பன்னாதீங்க\nபோட்டோவை பாத்து ஏமாறாதீங்க', 'rating': 1}, {'title': 'RATHOD VIRENDRASINH', 'date': 'Reviewed in India on 7 September 2021', 'content': ' Bad results of camera it is accepted. But now camera not working. Vivo Y33s..... Please action to replace this peace / alternate immediately.\nThanks - 16/11/21', 'rating': 4}, {'title': 'Karthick', 'date': 'Reviewed in India on 30 August 2021', 'content': 'Camera quality is good, while on the flash light camera performance is very slow. Light weight and compact phone. Black color is looks great. Phone sounds is also gently given. I like this phone...', 'rating': 4}, {'title': 'Amz Customer', 'date': 'Reviewed in India on 20 October 2021', 'content': "Vivo Y33s is my 4th Vivo mobile, n m utterly disappointed with it, all the useful features have been removed in this model. Within 1 week I've had touch screen issues, doesn't connect to WiFi or mobile internet, doesn't detect SD card, shows 128 GB storage, but doesn't save any files, worst of all is the front camera, images are not the best, I regret buying this mobile", 'rating': 1}, {'title': 'Nirmal', 'date': 'Reviewed in India on 3 October 2021', 'content': 'This is a value for money product, massive data space , No Lag , performance , large and high resolution screen for price and charging speed and finish of product is very good as well been using it for for 1.5 months no deterioration in quality observed extremely statisfied by the product,', 'rating': 5}, {'title': 'Vijay Shinde', 'date': 'Reviewed in India on 15 October 2021', 'content': 'same supplier refuse me delivery in my pincoode 400703 location amazon no control on supplier\nLot of bugs in software difficult to configure Bluetooth with other device', 'rating': 1}, {'title': 'Amazon Customer', 'date': 'Reviewed in India on 23 September 2021', 'content': 'TooPros- 1. Slim & sleek design\n2. Better front camera\n3.Good battery life, one day for your daily activity\n4. Good sound quality - surround sound\nCons-\n1. Needs more improvement in fast charging as only 18 watt fast charging given, can charge phone in 1.5 hrs\n2.Needs quad camera as triple camera given in back side (picture quality in rear camera was not good)\n3.Littlebit handy\n4. Needs Amoled display at this price range as lcd display is given\n5. Needs atleast 90 hz refresh rate as it supports only 60 hz', 'rating': 4}, {'title': 'MH 24', 'date': 'Reviewed in India on 22 September 2021', 'content': 'Best Camera, plz first settings camera always best performance\nBattery backup best\nVivo always best', 'rating': 5}, {'title': 'Akhil', 'date': 'Reviewed in India on 13 September 2021', 'content': 'Camera is very bad worst', 'rating': 3}, {'title': 'Bobby Naidu', 'date': 'Reviewed in India on 18 September 2021', 'content': 'Good 8gb ram varient at this price. Only draw back is the heating issue while gaming.', 'rating': 4}]

# %%
filename='product_review.csv'
pd.DataFrame(data).to_csv(filename,index=None)

# %%
product=pd.read_csv("C:/Users/HP/digipython/Major_project/.streamlit/product_review.csv")
product
# Out:
#                  title                                    date  \
# 0           ANDISAMY C  Reviewed in India on 11 September 2021
# 1  RATHOD VIRENDRASINH   Reviewed in India on 7 September 2021
# 2             Karthick     Reviewed in India on 30 August 2021
# 3         Amz Customer    Reviewed in India on 20 October 2021
# 4               Nirmal     Reviewed in India on 3 October 2021
# 5         Vijay Shinde    Reviewed in India on 15 October 2021
# 6      Amazon Customer  Reviewed in India on 23 September 2021
# 7                MH 24  Reviewed in India on 22 September 2021
# 8                Akhil  Reviewed in India on 13 September 2021
# 9          Bobby Naidu  Reviewed in India on 18 September 2021
#
#                                              content  rating
# 0  கேமரா வேஸ்ட் .தயவு செய்து பணத்தை வேஸ்ட் பன்னாத...       1
# 1   Bad results of camera it is accepted. But now...       4
# 2  Camera quality is good, while on the flash lig...       4
# 3  Vivo Y33s is my 4th Vivo mobile, n m utterly d...       1
# 4  This is a value for money product, massive dat...       5
# 5  same supplier refuse me delivery in my pincood...       1
# 6  TooPros- 1. Slim & sleek design\n2. Better fro...       4
# 7  Best Camera, plz first settings camera always ...       5
# 8                           Camera is very bad worst       3
# 9  Good 8gb ram varient at this price. Only draw ...       4

# %%
product.tail()
# Out:
#              title                                    date  \
# 5     Vijay Shinde    Reviewed in India on 15 October 2021
# 6  Amazon Customer  Reviewed in India on 23 September 2021
# 7            MH 24  Reviewed in India on 22 September 2021
# 8            Akhil  Reviewed in India on 13 September 2021
# 9      Bobby Naidu  Reviewed in India on 18 September 2021
#
#                                              content  rating
# 5  same supplier refuse me delivery in my pincood...       1
# 6  TooPros- 1. Slim & sleek design\n2. Better fro...       4
# 7  Best Camera, plz first settings camera always ...       5
# 8                           Camera is very bad worst       3
# 9  Good 8gb ram varient at this price. Only draw ...       4

# %% [markdown]
# # FUNCTION CREATION

# %%
def start(product_link = "https://www.amazon.in/Vivo-Y33s-Storage-Additional-Exchange/dp/B08ZJR6BMV/ref=sr_1_1_sspa?keywords=mobiles&qid=1644125639&sprefix=mobil%2Caps%2C319&sr=8-1-spons&psc=1&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUEzVldHMUxHVVAzRlhQJmVuY3J5cHRlZElkPUEwMDc5NTY0MzBGRUk4Rko0RkY3TCZlbmNyeXB0ZWRBZElkPUEwNzAwMzgwMzQxR1FPSFZZT0daMiZ3aWRnZXROYW1lPXNwX2F0ZiZhY3Rpb249Y2xpY2tSZWRpcmVjdCZkb05vdExvZ0NsaWNrPXRydWU="):
    driver=webdriver.Chrome(ChromeDriverManager().install())
    driver.maximize_window()
    driver.get(product_link)
    review_page_link = driver.find_element(by='id',value="reviews-medley-footer").find_element_by_css_selector('a.a-link-emphasis').get_attribute('href')
    return driver,review_page_link

def extract(driver,link,page = 1):    
    review_next_link=f'{link}&pageNumber={page}'
    driver.get(review_next_link)
    review_area = driver.find_element_by_css_selector('#cm_cr-review_list')
    review_list = review_area.find_elements_by_css_selector('.review')
    if review_list:
        print(len(review_list))
    else:
        print('crap')

    data=[]
    for item in review_list:
        try:
            title=item.find_element_by_css_selector('span.a-profile-name').text
        except:
            title=""
        try:
            date=item.find_element_by_css_selector('span.a-size-base.a-color-secondary.review-date').text
        except:
            date=""
        
        try:
            content=item.find_element_by_css_selector('span.a-size-base.review-text.review-text-content').text
        except:
            content=""
        try:
            verified_pro=item.find_element_by_css_selector('span.a-size-mini.a-color-state.a-text-bold').text
        except:
            verified_pro=""
        try:
            rating=item.find_elements_by_css_selector('i.a-icon-star')[-1]
            rating=rating.get_attribute('class')
            if "5" in rating:
                rating=5
            elif "4" in rating:
                rating=4
            elif "3" in rating:
                rating=3
            elif "2" in rating:
                rating=2
            elif "1" in rating:
                rating=1
        except:
            rating=""
        data.append({
            'title':title,
            'date':date,
            'content':content,
            'verified_product':verified_pro,
            'rating':rating
        })
    return data

def save(reviews,filename='product_review.csv'):
    from sqlalchemy import create_engine
    engine = create_engine('sqlite:///reviews.sqlite', echo=True)
    df = pd.DataFrame(reviews)
    df.to_csv(filename,index=None)
    df.to_sql('reviews', con=engine,if_exists='append')

# %%
driver, link = start()
page = 1
review_list = []
while True:
    try:
        data = extract(driver,link,page)
        if len(data)>0:
            review_list.extend(data)
            page+=1
        else:
            print("no data")
            break
    except Exception as e:
        print(e)
        break
    
driver.close()
if len(review_list)>0:
    save(review_list,'vivo_reviews.csv')
else:
    print("no reviews")
# Out:
# [WDM] -
#
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 101.0.4951
# [WDM] - Get LATEST driver version for 101.0.4951
# [WDM] - Driver [C:\Users\HP\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache
# C:\Users\HP\AppData\Local\Temp/ipykernel_29872/3135262088.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(ChromeDriverManager().install())
# C:\Users\HP\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webelement.py:483: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# C:\Users\HP\AppData\Local\Temp/ipykernel_29872/3135262088.py:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   review_area = driver.find_element_by_css_selector('#cm_cr-review_list')
# C:\Users\HP\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webelement.py:501: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")
# crap
# 'NoneType' object is not iterable
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29872/1221537292.py in <module>
#      15         break
#      16
# ---> 17 driver.close()
#      18 if len(review_list)>0:
#      19     save(review_list,'vivo_reviews.csv')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in close(self)
#     929                 driver.close()
#     930         """
# --> 931         self.execute(Command.CLOSE)
#     932
#     933     def quit(self) -> None:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     416         response = self.command_executor.execute(driver_command, params)
#     417         if response:
# --> 418             self.error_handler.check_response(response)
#     419             response['value'] = self._unwrap_value(
#     420                 response.get('value', None))
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241                 alert_text = value['alert'].get('text')
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#     244
#     245     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=101.0.4951.54)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x003DB8F3+2406643]
# 	Ordinal0 [0x0036AF31+1945393]
# 	Ordinal0 [0x0025C610+837136]
# 	Ordinal0 [0x00250442+787522]
# 	Ordinal0 [0x00243F21+737057]
# 	Ordinal0 [0x002AA6F0+1156848]
# 	Ordinal0 [0x002A4243+1131075]
# 	Ordinal0 [0x0027E636+976438]
# 	Ordinal0 [0x0027F546+980294]
# 	GetHandleVerifier [0x00649612+2498066]
# 	GetHandleVerifier [0x0063C920+2445600]
# 	GetHandleVerifier [0x00474F2A+579370]
# 	GetHandleVerifier [0x00473D36+574774]
# 	Ordinal0 [0x00371C0B+1973259]
# 	Ordinal0 [0x00376688+1992328]
# 	Ordinal0 [0x00376775+1992565]
# 	Ordinal0 [0x0037F8D1+2029777]
# 	BaseThreadInitThunk [0x76EDFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77107A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77107A6E+238]

# %%
product=pd.read_csv("vivo_reviews.csv")
product
# Out:
#                            title                                    date  \
# 0                     ANDISAMY C  Reviewed in India on 11 September 2021
# 1            RATHOD VIRENDRASINH   Reviewed in India on 7 September 2021
# 2                       Karthick     Reviewed in India on 30 August 2021
# 3                   Amz Customer    Reviewed in India on 20 October 2021
# 4                         Nirmal     Reviewed in India on 3 October 2021
# ..                           ...                                     ...
# 225                      Jijo m.      Reviewed in India on 21 March 2022
# 226  Mohd Arif khan balrampur UP      Reviewed in India on 10 April 2022
# 227              Amazon Customer      Reviewed in India on 23 March 2022
# 228                 manivannan j      Reviewed in India on 27 March 2022
# 229           Karun Kumar sharma      Reviewed in India on 31 March 2022
#
#                                                content   verified_product  \
# 0    கேமரா வேஸ்ட் .தயவு செய்து பணத்தை வேஸ்ட் பன்னாத...  Verified Purchase
# 1     Bad results of camera it is accepted. But now...  Verified Purchase
# 2    Camera quality is good, while on the flash lig...  Verified Purchase
# 3    Vivo Y33s is my 4th Vivo mobile, n m utterly d...  Verified Purchase
# 4    This is a value for money product, massive dat...  Verified Purchase
# ..                                                 ...                ...
# 225  Very sad about your service. After three days ...  Verified Purchase
# 226  Finger print very good work battery life good ...  Verified Purchase
# 227                       Good working and nice mobile  Verified Purchase
# 228                       Super battery good camera ok  Verified Purchase
# 229                               Mobile damage aaya h  Verified Purchase
#
#      rating
# 0         1
# 1         4
# 2         4
# 3         1
# 4         5
# ..      ...
# 225       1
# 226       5
# 227       5
# 228       4
# 229       1
#
# [230 rows x 5 columns]

# %%
product.date=product.date.apply(lambda s:"-".join(s.split()[-3:]))
product.to_csv('vivo_reviews.csv')
product
# Out:
#                            title               date  \
# 0                     ANDISAMY C  11-September-2021
# 1            RATHOD VIRENDRASINH   7-September-2021
# 2                       Karthick     30-August-2021
# 3                   Amz Customer    20-October-2021
# 4                         Nirmal     3-October-2021
# ..                           ...                ...
# 225                      Jijo m.      21-March-2022
# 226  Mohd Arif khan balrampur UP      10-April-2022
# 227              Amazon Customer      23-March-2022
# 228                 manivannan j      27-March-2022
# 229           Karun Kumar sharma      31-March-2022
#
#                                                content   verified_product  \
# 0    கேமரா வேஸ்ட் .தயவு செய்து பணத்தை வேஸ்ட் பன்னாத...  Verified Purchase
# 1     Bad results of camera it is accepted. But now...  Verified Purchase
# 2    Camera quality is good, while on the flash lig...  Verified Purchase
# 3    Vivo Y33s is my 4th Vivo mobile, n m utterly d...  Verified Purchase
# 4    This is a value for money product, massive dat...  Verified Purchase
# ..                                                 ...                ...
# 225  Very sad about your service. After three days ...  Verified Purchase
# 226  Finger print very good work battery life good ...  Verified Purchase
# 227                       Good working and nice mobile  Verified Purchase
# 228                       Super battery good camera ok  Verified Purchase
# 229                               Mobile damage aaya h  Verified Purchase
#
#      rating
# 0         1
# 1         4
# 2         4
# 3         1
# 4         5
# ..      ...
# 225       1
# 226       5
# 227       5
# 228       4
# 229       1
#
# [230 rows x 5 columns]

# %%
product['date'] = pd.to_datetime(product['date'])
product.to_csv('vivo_reviews.csv')
product
# Out:
#                            title       date  \
# 0                     ANDISAMY C 2021-09-11
# 1            RATHOD VIRENDRASINH 2021-09-07
# 2                       Karthick 2021-08-30
# 3                   Amz Customer 2021-10-20
# 4                         Nirmal 2021-10-03
# ..                           ...        ...
# 225                      Jijo m. 2022-03-21
# 226  Mohd Arif khan balrampur UP 2022-04-10
# 227              Amazon Customer 2022-03-23
# 228                 manivannan j 2022-03-27
# 229           Karun Kumar sharma 2022-03-31
#
#                                                content   verified_product  \
# 0    கேமரா வேஸ்ட் .தயவு செய்து பணத்தை வேஸ்ட் பன்னாத...  Verified Purchase
# 1     Bad results of camera it is accepted. But now...  Verified Purchase
# 2    Camera quality is good, while on the flash lig...  Verified Purchase
# 3    Vivo Y33s is my 4th Vivo mobile, n m utterly d...  Verified Purchase
# 4    This is a value for money product, massive dat...  Verified Purchase
# ..                                                 ...                ...
# 225  Very sad about your service. After three days ...  Verified Purchase
# 226  Finger print very good work battery life good ...  Verified Purchase
# 227                       Good working and nice mobile  Verified Purchase
# 228                       Super battery good camera ok  Verified Purchase
# 229                               Mobile damage aaya h  Verified Purchase
#
#      rating
# 0         1
# 1         4
# 2         4
# 3         1
# 4         5
# ..      ...
# 225       1
# 226       5
# 227       5
# 228       4
# 229       1
#
# [230 rows x 5 columns]
